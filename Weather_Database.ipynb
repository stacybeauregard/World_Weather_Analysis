# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 718

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.

for i, city in enumerate(cities):

    # Group cities in sets of 100 for logging purposes.
    
    if (i % 100 == 0 and i >= 100):
        set_count += 1
        record_count = 1
        

    # Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]


        
       # Append the city information into weather_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                            })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 1 | mogadishu
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | thompson
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | bereda
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | sao joao da barra
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | hammerfest
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | laguna
# Processing Record 15 of Set 1 | emba
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | torbay
# Processing Record 18 of Set 1 | sitka
# Processing Record 19 of Set 1 | shimoda
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | kousseri
# Processing Record 23 of Set 1 | porto walter
# Processing Record 24 of Set 1 | tuatapere
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | byron bay
# Processing Record 28 of Set 1 | malakal
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | orebro
# Processing Record 33 of Set 1 | sangmelima
# Processing Record 34 of Set 1 | hasaki
# Processing Record 35 of Set 1 | natchitoches
# Processing Record 36 of Set 1 | nerchinskiy zavod
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | dengzhou
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | hualmay
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | tateyama
# Processing Record 47 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | saryozek
# Processing Record 51 of Set 1 | kimbe
# Processing Record 52 of Set 1 | bengkulu
# Processing Record 53 of Set 1 | nikolskoye
# Processing Record 54 of Set 1 | beringovskiy
# Processing Record 55 of Set 1 | saldanha
# Processing Record 56 of Set 1 | necochea
# Processing Record 57 of Set 1 | clyde river
# Processing Record 58 of Set 1 | alofi
# Processing Record 59 of Set 1 | provideniya
# Processing Record 60 of Set 1 | gold coast
# Processing Record 61 of Set 1 | port alfred
# Processing Record 62 of Set 1 | carnarvon
# Processing Record 63 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 64 of Set 1 | qaqortoq
# Processing Record 65 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 66 of Set 1 | hobart
# Processing Record 67 of Set 1 | hithadhoo
# Processing Record 68 of Set 1 | bluff
# Processing Record 69 of Set 1 | jamestown
# Processing Record 70 of Set 1 | rawson
# Processing Record 71 of Set 1 | kahului
# Processing Record 72 of Set 1 | avarua
# Processing Record 73 of Set 1 | ovalle
# Processing Record 74 of Set 1 | crestview
# Processing Record 75 of Set 1 | hilo
# Processing Record 76 of Set 1 | mar del plata
# Processing Record 77 of Set 1 | butaritari
# Processing Record 78 of Set 1 | ukiah
# Processing Record 79 of Set 1 | yelovo
# Processing Record 80 of Set 1 | yulara
# Processing Record 81 of Set 1 | broken hill
# Processing Record 82 of Set 1 | huntsville
# Processing Record 83 of Set 1 | mitu
# Processing Record 84 of Set 1 | muscat
# Processing Record 85 of Set 1 | polyarnyy
# Processing Record 86 of Set 1 | porangatu
# Processing Record 87 of Set 1 | coihaique
# Processing Record 88 of Set 1 | daru
# Processing Record 89 of Set 1 | uberaba
# Processing Record 90 of Set 1 | chalmette
# Processing Record 91 of Set 1 | vila velha
# Processing Record 92 of Set 1 | ayr
# Processing Record 93 of Set 1 | gizycko
# Processing Record 94 of Set 1 | faanui
# Processing Record 95 of Set 1 | saskylakh
# Processing Record 96 of Set 1 | changji
# Processing Record 97 of Set 1 | new norfolk
# Processing Record 98 of Set 1 | grindavik
# Processing Record 99 of Set 1 | havre
# Processing Record 100 of Set 1 | tottori
# Processing Record 1 of Set 2 | mhango
# Processing Record 2 of Set 2 | konevo
# Processing Record 3 of Set 2 | sola
# Processing Record 4 of Set 2 | cayenne
# Processing Record 5 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 2 | mehriz
# Processing Record 7 of Set 2 | sananduva
# Processing Record 8 of Set 2 | yinchuan
# Processing Record 9 of Set 2 | colac
# Processing Record 10 of Set 2 | aporawan
# City not found. Skipping...
# Processing Record 11 of Set 2 | maldonado
# Processing Record 12 of Set 2 | gobabis
# Processing Record 13 of Set 2 | ilulissat
# Processing Record 14 of Set 2 | sao mateus
# Processing Record 15 of Set 2 | klaksvik
# Processing Record 16 of Set 2 | honiara
# Processing Record 17 of Set 2 | korla
# Processing Record 18 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 2 | katsuura
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | shirokiy
# Processing Record 22 of Set 2 | kamaishi
# Processing Record 23 of Set 2 | san cristobal
# Processing Record 24 of Set 2 | ayorou
# Processing Record 25 of Set 2 | manicore
# Processing Record 26 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 2 | samarai
# Processing Record 28 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 2 | cap malheureux
# Processing Record 30 of Set 2 | brae
# Processing Record 31 of Set 2 | nanortalik
# Processing Record 32 of Set 2 | pincher creek
# Processing Record 33 of Set 2 | dois corregos
# Processing Record 34 of Set 2 | karpathos
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | jackson
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | norman wells
# Processing Record 40 of Set 2 | cungrea
# Processing Record 41 of Set 2 | khatanga
# Processing Record 42 of Set 2 | port macquarie
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | palembang
# Processing Record 45 of Set 2 | ixtapa
# Processing Record 46 of Set 2 | hovd
# Processing Record 47 of Set 2 | jocon
# Processing Record 48 of Set 2 | cherskiy
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 51 of Set 2 | atuona
# Processing Record 52 of Set 2 | ambilobe
# Processing Record 53 of Set 2 | ponta do sol
# Processing Record 54 of Set 2 | avera
# Processing Record 55 of Set 2 | mujiayingzi
# Processing Record 56 of Set 2 | vila franca do campo
# Processing Record 57 of Set 2 | tiarei
# Processing Record 58 of Set 2 | abu samrah
# Processing Record 59 of Set 2 | sur
# Processing Record 60 of Set 2 | northam
# Processing Record 61 of Set 2 | half moon bay
# Processing Record 62 of Set 2 | katastarion
# Processing Record 63 of Set 2 | kodiak
# Processing Record 64 of Set 2 | rudnogorsk
# Processing Record 65 of Set 2 | sao lourenco do sul
# Processing Record 66 of Set 2 | te anau
# Processing Record 67 of Set 2 | werda
# Processing Record 68 of Set 2 | pisco
# Processing Record 69 of Set 2 | hesperia
# Processing Record 70 of Set 2 | east london
# Processing Record 71 of Set 2 | kavieng
# Processing Record 72 of Set 2 | lavrentiya
# Processing Record 73 of Set 2 | bemidji
# Processing Record 74 of Set 2 | fiche
# Processing Record 75 of Set 2 | bhind
# Processing Record 76 of Set 2 | kondinskoye
# Processing Record 77 of Set 2 | saint-philippe
# Processing Record 78 of Set 2 | san quintin
# Processing Record 79 of Set 2 | evanston
# Processing Record 80 of Set 2 | hericourt
# Processing Record 81 of Set 2 | putina
# Processing Record 82 of Set 2 | katherine
# Processing Record 83 of Set 2 | beidao
# Processing Record 84 of Set 2 | lompoc
# Processing Record 85 of Set 2 | airai
# Processing Record 86 of Set 2 | pacific grove
# Processing Record 87 of Set 2 | huangmei
# Processing Record 88 of Set 2 | serov
# Processing Record 89 of Set 2 | namibe
# Processing Record 90 of Set 2 | tukrah
# Processing Record 91 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 92 of Set 2 | port hedland
# Processing Record 93 of Set 2 | conde
# Processing Record 94 of Set 2 | dhidhdhoo
# Processing Record 95 of Set 2 | meulaboh
# Processing Record 96 of Set 2 | bethel
# Processing Record 97 of Set 2 | roswell
# Processing Record 98 of Set 2 | atbasar
# Processing Record 99 of Set 2 | nizwa
# Processing Record 100 of Set 2 | torres
# Processing Record 1 of Set 3 | garowe
# Processing Record 2 of Set 3 | ancud
# Processing Record 3 of Set 3 | marawi
# Processing Record 4 of Set 3 | boden
# Processing Record 5 of Set 3 | ostrovnoy
# Processing Record 6 of Set 3 | praya
# Processing Record 7 of Set 3 | souillac
# Processing Record 8 of Set 3 | andenes
# Processing Record 9 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 3 | oriximina
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | bejar
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 3 | nome
# Processing Record 16 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 3 | chuy
# Processing Record 18 of Set 3 | fort frances
# Processing Record 19 of Set 3 | puerto colombia
# Processing Record 20 of Set 3 | ruidoso
# Processing Record 21 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 3 | westport
# Processing Record 23 of Set 3 | caravelas
# Processing Record 24 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 3 | mount gambier
# Processing Record 26 of Set 3 | dawlatabad
# Processing Record 27 of Set 3 | ormara
# Processing Record 28 of Set 3 | witrivier
# City not found. Skipping...
# Processing Record 29 of Set 3 | haines junction
# Processing Record 30 of Set 3 | vytegra
# Processing Record 31 of Set 3 | narsaq
# Processing Record 32 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 3 | hirara
# Processing Record 34 of Set 3 | one hundred mile house
# City not found. Skipping...
# Processing Record 35 of Set 3 | wajima
# Processing Record 36 of Set 3 | burica
# City not found. Skipping...
# Processing Record 37 of Set 3 | bolivar
# Processing Record 38 of Set 3 | akureyri
# Processing Record 39 of Set 3 | kurush
# Processing Record 40 of Set 3 | cascais
# Processing Record 41 of Set 3 | madang
# Processing Record 42 of Set 3 | cururupu
# Processing Record 43 of Set 3 | marsala
# Processing Record 44 of Set 3 | micheweni
# Processing Record 45 of Set 3 | zhigansk
# Processing Record 46 of Set 3 | nishihara
# Processing Record 47 of Set 3 | atar
# Processing Record 48 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 3 | lapeer
# Processing Record 51 of Set 3 | saint george
# Processing Record 52 of Set 3 | seoul
# Processing Record 53 of Set 3 | newport
# Processing Record 54 of Set 3 | vuktyl
# Processing Record 55 of Set 3 | havelock
# Processing Record 56 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 57 of Set 3 | istok
# Processing Record 58 of Set 3 | quatre cocos
# Processing Record 59 of Set 3 | cidreira
# Processing Record 60 of Set 3 | nuuk
# Processing Record 61 of Set 3 | sungairaya
# Processing Record 62 of Set 3 | tiksi
# Processing Record 63 of Set 3 | bathsheba
# Processing Record 64 of Set 3 | esperance
# Processing Record 65 of Set 3 | olafsvik
# Processing Record 66 of Set 3 | bucerias
# Processing Record 67 of Set 3 | howard springs
# Processing Record 68 of Set 3 | lata
# Processing Record 69 of Set 3 | kaitangata
# Processing Record 70 of Set 3 | anqing
# Processing Record 71 of Set 3 | coquimbo
# Processing Record 72 of Set 3 | rio gallegos
# Processing Record 73 of Set 3 | rio grande
# Processing Record 74 of Set 3 | parker
# Processing Record 75 of Set 3 | reconquista
# Processing Record 76 of Set 3 | ulundi
# Processing Record 77 of Set 3 | sayyan
# Processing Record 78 of Set 3 | todos santos
# Processing Record 79 of Set 3 | coari
# Processing Record 80 of Set 3 | salalah
# Processing Record 81 of Set 3 | marzuq
# Processing Record 82 of Set 3 | popondetta
# Processing Record 83 of Set 3 | la palma
# Processing Record 84 of Set 3 | belyy yar
# Processing Record 85 of Set 3 | sulangan
# Processing Record 86 of Set 3 | victoria
# Processing Record 87 of Set 3 | parras
# City not found. Skipping...
# Processing Record 88 of Set 3 | ericeira
# Processing Record 89 of Set 3 | college
# Processing Record 90 of Set 3 | sarmanovo
# Processing Record 91 of Set 3 | hambantota
# Processing Record 92 of Set 3 | san vicente
# Processing Record 93 of Set 3 | thinadhoo
# Processing Record 94 of Set 3 | aklavik
# Processing Record 95 of Set 3 | senanga
# Processing Record 96 of Set 3 | lafia
# Processing Record 97 of Set 3 | turukhansk
# Processing Record 98 of Set 3 | impfondo
# Processing Record 99 of Set 3 | aksu
# Processing Record 100 of Set 3 | nelson bay
# Processing Record 1 of Set 4 | palu
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | berlevag
# Processing Record 4 of Set 4 | upernavik
# Processing Record 5 of Set 4 | brownfield
# Processing Record 6 of Set 4 | leningradskiy
# Processing Record 7 of Set 4 | dunedin
# Processing Record 8 of Set 4 | toila
# Processing Record 9 of Set 4 | tigil
# Processing Record 10 of Set 4 | kirksville
# Processing Record 11 of Set 4 | qabis
# City not found. Skipping...
# Processing Record 12 of Set 4 | afmadu
# City not found. Skipping...
# Processing Record 13 of Set 4 | liuzhou
# Processing Record 14 of Set 4 | mailani
# Processing Record 15 of Set 4 | madridejos
# Processing Record 16 of Set 4 | havre-saint-pierre
# Processing Record 17 of Set 4 | arrecife
# Processing Record 18 of Set 4 | graaff-reinet
# Processing Record 19 of Set 4 | cockburn town
# Processing Record 20 of Set 4 | kruisfontein
# Processing Record 21 of Set 4 | verkhniy avzyan
# Processing Record 22 of Set 4 | kishni
# Processing Record 23 of Set 4 | kununurra
# Processing Record 24 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 25 of Set 4 | buala
# Processing Record 26 of Set 4 | piacabucu
# Processing Record 27 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 4 | asau
# Processing Record 29 of Set 4 | mahbubabad
# Processing Record 30 of Set 4 | saint-augustin
# Processing Record 31 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 4 | pitimbu
# Processing Record 33 of Set 4 | port elizabeth
# Processing Record 34 of Set 4 | talaya
# Processing Record 35 of Set 4 | kemijarvi
# Processing Record 36 of Set 4 | buin
# Processing Record 37 of Set 4 | camana
# Processing Record 38 of Set 4 | san patricio
# Processing Record 39 of Set 4 | kalmunai
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | sambava
# Processing Record 42 of Set 4 | fortuna
# Processing Record 43 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 44 of Set 4 | muravlenko
# Processing Record 45 of Set 4 | soure
# Processing Record 46 of Set 4 | constitucion
# Processing Record 47 of Set 4 | masindi
# Processing Record 48 of Set 4 | bilibino
# Processing Record 49 of Set 4 | sivas
# Processing Record 50 of Set 4 | pachino
# Processing Record 51 of Set 4 | neyshabur
# Processing Record 52 of Set 4 | otesani
# Processing Record 53 of Set 4 | tucuman
# Processing Record 54 of Set 4 | broome
# Processing Record 55 of Set 4 | walvis bay
# Processing Record 56 of Set 4 | kloulklubed
# Processing Record 57 of Set 4 | muroto
# Processing Record 58 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 59 of Set 4 | marsa matruh
# Processing Record 60 of Set 4 | whitianga
# Processing Record 61 of Set 4 | ponta delgada
# Processing Record 62 of Set 4 | altay
# Processing Record 63 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 64 of Set 4 | pangnirtung
# Processing Record 65 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 66 of Set 4 | evensk
# Processing Record 67 of Set 4 | inuvik
# Processing Record 68 of Set 4 | yelizavetino
# Processing Record 69 of Set 4 | san rafael
# Processing Record 70 of Set 4 | zyukayka
# Processing Record 71 of Set 4 | lagoa
# Processing Record 72 of Set 4 | luquillo
# Processing Record 73 of Set 4 | rapid valley
# Processing Record 74 of Set 4 | colares
# Processing Record 75 of Set 4 | anadyr
# Processing Record 76 of Set 4 | amapa
# Processing Record 77 of Set 4 | orangeburg
# Processing Record 78 of Set 4 | paita
# Processing Record 79 of Set 4 | imbituba
# Processing Record 80 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 81 of Set 4 | linhares
# Processing Record 82 of Set 4 | severo-kurilsk
# Processing Record 83 of Set 4 | beloha
# Processing Record 84 of Set 4 | meadow lake
# Processing Record 85 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 86 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 87 of Set 4 | southbridge
# Processing Record 88 of Set 4 | harper
# Processing Record 89 of Set 4 | maceio
# Processing Record 90 of Set 4 | tazmalt
# Processing Record 91 of Set 4 | santa cruz
# Processing Record 92 of Set 4 | melfort
# Processing Record 93 of Set 4 | padang
# Processing Record 94 of Set 4 | ewa beach
# Processing Record 95 of Set 4 | ulladulla
# Processing Record 96 of Set 4 | gornopravdinsk
# Processing Record 97 of Set 4 | sonoita
# Processing Record 98 of Set 4 | kitimat
# Processing Record 99 of Set 4 | vardo
# Processing Record 100 of Set 4 | kapustin yar-1
# City not found. Skipping...
# Processing Record 1 of Set 5 | derzhavinsk
# Processing Record 2 of Set 5 | shingu
# Processing Record 3 of Set 5 | bouar
# Processing Record 4 of Set 5 | valparaiso
# Processing Record 5 of Set 5 | porec
# Processing Record 6 of Set 5 | gladstone
# Processing Record 7 of Set 5 | gribanovskiy
# Processing Record 8 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 5 | cabo san lucas
# Processing Record 10 of Set 5 | makakilo city
# Processing Record 11 of Set 5 | acapulco
# Processing Record 12 of Set 5 | bambanglipuro
# Processing Record 13 of Set 5 | autun
# Processing Record 14 of Set 5 | tessalit
# Processing Record 15 of Set 5 | hobyo
# Processing Record 16 of Set 5 | tongliao
# Processing Record 17 of Set 5 | sharan
# Processing Record 18 of Set 5 | berbera
# Processing Record 19 of Set 5 | yangjiang
# Processing Record 20 of Set 5 | cam ranh
# Processing Record 21 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 5 | straumen
# Processing Record 23 of Set 5 | innisfail
# Processing Record 24 of Set 5 | talnakh
# Processing Record 25 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 5 | kamalpur
# Processing Record 27 of Set 5 | kvitok
# Processing Record 28 of Set 5 | pedernales
# Processing Record 29 of Set 5 | tura
# Processing Record 30 of Set 5 | huaiyin
# Processing Record 31 of Set 5 | pochutla
# Processing Record 32 of Set 5 | goma
# Processing Record 33 of Set 5 | tarakan
# Processing Record 34 of Set 5 | poum
# Processing Record 35 of Set 5 | ayios petros
# City not found. Skipping...
# Processing Record 36 of Set 5 | katima mulilo
# Processing Record 37 of Set 5 | pandan
# Processing Record 38 of Set 5 | sangareddi
# Processing Record 39 of Set 5 | goure
# Processing Record 40 of Set 5 | davila
# Processing Record 41 of Set 5 | port hardy
# Processing Record 42 of Set 5 | portland
# Processing Record 43 of Set 5 | martapura
# Processing Record 44 of Set 5 | coromandel
# Processing Record 45 of Set 5 | geraldton
# Processing Record 46 of Set 5 | mitsamiouli
# Processing Record 47 of Set 5 | sorland
# Processing Record 48 of Set 5 | kedrovyy
# Processing Record 49 of Set 5 | lorengau
# Processing Record 50 of Set 5 | lebu
# Processing Record 51 of Set 5 | libreville
# Processing Record 52 of Set 5 | valdivia
# Processing Record 53 of Set 5 | taguisa
# Processing Record 54 of Set 5 | hami
# Processing Record 55 of Set 5 | langsa
# Processing Record 56 of Set 5 | achacachi
# Processing Record 57 of Set 5 | shelburne
# Processing Record 58 of Set 5 | lodja
# Processing Record 59 of Set 5 | naze
# Processing Record 60 of Set 5 | hof
# Processing Record 61 of Set 5 | wembley
# Processing Record 62 of Set 5 | bulgan
# Processing Record 63 of Set 5 | codrington
# Processing Record 64 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 65 of Set 5 | porto santo
# Processing Record 66 of Set 5 | muzhi
# Processing Record 67 of Set 5 | kidero
# Processing Record 68 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 69 of Set 5 | clinton
# Processing Record 70 of Set 5 | riachao do jacuipe
# Processing Record 71 of Set 5 | sept-iles
# Processing Record 72 of Set 5 | zhuhai
# Processing Record 73 of Set 5 | zambezi
# Processing Record 74 of Set 5 | brandfort
# Processing Record 75 of Set 5 | saint-pierre
# Processing Record 76 of Set 5 | karratha
# Processing Record 77 of Set 5 | dongsheng
# Processing Record 78 of Set 5 | kemi
# Processing Record 79 of Set 5 | medina del campo
# Processing Record 80 of Set 5 | niono
# Processing Record 81 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 82 of Set 5 | odienne
# Processing Record 83 of Set 5 | grand-santi
# Processing Record 84 of Set 5 | lumphat
# Processing Record 85 of Set 5 | keetmanshoop
# Processing Record 86 of Set 5 | aras
# Processing Record 87 of Set 5 | lamont
# Processing Record 88 of Set 5 | hervey bay
# Processing Record 89 of Set 5 | malanje
# Processing Record 90 of Set 5 | sorong
# Processing Record 91 of Set 5 | krasnoselkup
# Processing Record 92 of Set 5 | nanakuli
# Processing Record 93 of Set 5 | abu kamal
# Processing Record 94 of Set 5 | pyaozerskiy
# Processing Record 95 of Set 5 | dangtu
# Processing Record 96 of Set 5 | valdemarpils
# Processing Record 97 of Set 5 | sukhobuzimskoye
# Processing Record 98 of Set 5 | pitanga
# Processing Record 99 of Set 5 | uruacu
# Processing Record 100 of Set 5 | titlagarh
# Processing Record 1 of Set 6 | wau
# Processing Record 2 of Set 6 | sokoni
# Processing Record 3 of Set 6 | paamiut
# Processing Record 4 of Set 6 | aljezur
# Processing Record 5 of Set 6 | fougamou
# Processing Record 6 of Set 6 | marsh harbour
# Processing Record 7 of Set 6 | dharchula
# Processing Record 8 of Set 6 | siuna
# Processing Record 9 of Set 6 | myitkyina
# Processing Record 10 of Set 6 | bumba
# Processing Record 11 of Set 6 | tarko-sale
# Processing Record 12 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 13 of Set 6 | vanimo
# Processing Record 14 of Set 6 | tevriz
# Processing Record 15 of Set 6 | neustadt
# Processing Record 16 of Set 6 | atambua
# Processing Record 17 of Set 6 | lakatoro
# Processing Record 18 of Set 6 | faya
# Processing Record 19 of Set 6 | maltahohe
# Processing Record 20 of Set 6 | guerrero negro
# Processing Record 21 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 6 | coahuayana
# Processing Record 23 of Set 6 | saint paul
# Processing Record 24 of Set 6 | new deer
# Processing Record 25 of Set 6 | okahandja
# Processing Record 26 of Set 6 | bardiyah
# Processing Record 27 of Set 6 | fare
# Processing Record 28 of Set 6 | fairbanks
# Processing Record 29 of Set 6 | paramonga
# Processing Record 30 of Set 6 | mount isa
# Processing Record 31 of Set 6 | ust-ordynskiy
# Processing Record 32 of Set 6 | arlit
# Processing Record 33 of Set 6 | emerald
# Processing Record 34 of Set 6 | tual
# Processing Record 35 of Set 6 | mehamn
# Processing Record 36 of Set 6 | mpulungu
# Processing Record 37 of Set 6 | karasjok
# Processing Record 38 of Set 6 | okhotsk
# Processing Record 39 of Set 6 | aleksandrovka
# Processing Record 40 of Set 6 | waipawa
# Processing Record 41 of Set 6 | isangel
# Processing Record 42 of Set 6 | tingi
# Processing Record 43 of Set 6 | celestun
# Processing Record 44 of Set 6 | nortelandia
# Processing Record 45 of Set 6 | sao filipe
# Processing Record 46 of Set 6 | camacha
# Processing Record 47 of Set 6 | hofn
# Processing Record 48 of Set 6 | mandalgovi
# Processing Record 49 of Set 6 | pahrump
# Processing Record 50 of Set 6 | abatskoye
# Processing Record 51 of Set 6 | valente
# Processing Record 52 of Set 6 | ronneby
# Processing Record 53 of Set 6 | slyudyanka
# Processing Record 54 of Set 6 | waingapu
# Processing Record 55 of Set 6 | yalchiki
# City not found. Skipping...
# Processing Record 56 of Set 6 | semnan
# Processing Record 57 of Set 6 | cabedelo
# Processing Record 58 of Set 6 | oranjemund
# Processing Record 59 of Set 6 | mnogovershinnyy
# Processing Record 60 of Set 6 | teya
# Processing Record 61 of Set 6 | husavik
# Processing Record 62 of Set 6 | snezhnogorsk
# Processing Record 63 of Set 6 | shakhovskaya
# Processing Record 64 of Set 6 | warrnambool
# Processing Record 65 of Set 6 | lasa
# Processing Record 66 of Set 6 | ottumwa
# Processing Record 67 of Set 6 | deputatskiy
# Processing Record 68 of Set 6 | fountain hills
# Processing Record 69 of Set 6 | presidencia roque saenz pena
# Processing Record 70 of Set 6 | griffith
# Processing Record 71 of Set 6 | hailar
# Processing Record 72 of Set 6 | turtas
# Processing Record 73 of Set 6 | dwarka
# Processing Record 74 of Set 6 | vilcun
# Processing Record 75 of Set 6 | tarija
# Processing Record 76 of Set 6 | jiaonan
# Processing Record 77 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 78 of Set 6 | nakamura
# Processing Record 79 of Set 6 | pocao de pedras
# Processing Record 80 of Set 6 | port blair
# Processing Record 81 of Set 6 | margate
# Processing Record 82 of Set 6 | kytlym
# City not found. Skipping...
# Processing Record 83 of Set 6 | batagay-alyta
# Processing Record 84 of Set 6 | kovylkino
# Processing Record 85 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 86 of Set 6 | lubao
# Processing Record 87 of Set 6 | la plaine
# Processing Record 88 of Set 6 | cap-aux-meules
# Processing Record 89 of Set 6 | asfi
# Processing Record 90 of Set 6 | yerbogachen
# Processing Record 91 of Set 6 | strezhevoy
# Processing Record 92 of Set 6 | miranda de ebro
# Processing Record 93 of Set 6 | constantine
# Processing Record 94 of Set 6 | bud
# Processing Record 95 of Set 6 | sandovo
# Processing Record 96 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 97 of Set 6 | prince rupert
# Processing Record 98 of Set 6 | santa cruz de la palma
# Processing Record 99 of Set 6 | taoudenni
# Processing Record 100 of Set 6 | bac lieu
# Processing Record 1 of Set 7 | mukhen
# Processing Record 2 of Set 7 | hibbing
# Processing Record 3 of Set 7 | arman
# Processing Record 4 of Set 7 | labuhan
# Processing Record 5 of Set 7 | ust-tsilma
# Processing Record 6 of Set 7 | yarmouth
# Processing Record 7 of Set 7 | trelew
# Processing Record 8 of Set 7 | jaciara
# Processing Record 9 of Set 7 | pagegiai
# Processing Record 10 of Set 7 | hoquiam
# Processing Record 11 of Set 7 | borgarnes
# Processing Record 12 of Set 7 | kungurtug
# Processing Record 13 of Set 7 | zaterechnyy
# Processing Record 14 of Set 7 | teguldet
# Processing Record 15 of Set 7 | envira
# Processing Record 16 of Set 7 | cheremukhovo
# Processing Record 17 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 7 | payakumbuh
# Processing Record 19 of Set 7 | urucara
# Processing Record 20 of Set 7 | udayagiri
# Processing Record 21 of Set 7 | zaysan
# Processing Record 22 of Set 7 | sinnamary
# Processing Record 23 of Set 7 | payo
# Processing Record 24 of Set 7 | itarema
# Processing Record 25 of Set 7 | zhob
# Processing Record 26 of Set 7 | barquisimeto
# Processing Record 27 of Set 7 | miranorte
# City not found. Skipping...
# Processing Record 28 of Set 7 | lianzhou
# Processing Record 29 of Set 7 | saint-paul-les-dax
# Processing Record 30 of Set 7 | aden
# Processing Record 31 of Set 7 | touros
# Processing Record 32 of Set 7 | dakar
# Processing Record 33 of Set 7 | kollam
# Processing Record 34 of Set 7 | iwanai
# Processing Record 35 of Set 7 | udachnyy
# Processing Record 36 of Set 7 | mangrul pir
# Processing Record 37 of Set 7 | kutum
# Processing Record 38 of Set 7 | komsomolskiy
# Processing Record 39 of Set 7 | huamachuco
# Processing Record 40 of Set 7 | khorixas
# Processing Record 41 of Set 7 | chickasha
# Processing Record 42 of Set 7 | cairns
# Processing Record 43 of Set 7 | roebourne
# Processing Record 44 of Set 7 | ardino
# Processing Record 45 of Set 7 | mulhouse
# Processing Record 46 of Set 7 | outjo
# Processing Record 47 of Set 7 | redmond
# Processing Record 48 of Set 7 | bambari
# Processing Record 49 of Set 7 | disna
# Processing Record 50 of Set 7 | pietersburg
# Processing Record 51 of Set 7 | eslov
# Processing Record 52 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 53 of Set 7 | anloga
# Processing Record 54 of Set 7 | chino valley
# Processing Record 55 of Set 7 | treinta y tres
# Processing Record 56 of Set 7 | porto novo
# Processing Record 57 of Set 7 | matara
# Processing Record 58 of Set 7 | cape canaveral
# Processing Record 59 of Set 7 | takoradi
# Processing Record 60 of Set 7 | san policarpo
# Processing Record 61 of Set 7 | bobo dioulasso
# Processing Record 62 of Set 7 | les cayes
# Processing Record 63 of Set 7 | santa ana
# Processing Record 64 of Set 7 | mount forest
# Processing Record 65 of Set 7 | chimoio
# Processing Record 66 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 67 of Set 7 | milkovo
# Processing Record 68 of Set 7 | arona
# Processing Record 69 of Set 7 | anchorage
# Processing Record 70 of Set 7 | manohar thana
# Processing Record 71 of Set 7 | tiznit
# Processing Record 72 of Set 7 | konotop
# Processing Record 73 of Set 7 | sapozhok
# Processing Record 74 of Set 7 | basco
# Processing Record 75 of Set 7 | bilma
# Processing Record 76 of Set 7 | hamilton
# Processing Record 77 of Set 7 | nardaran
# Processing Record 78 of Set 7 | egvekinot
# Processing Record 79 of Set 7 | muyezerskiy
# Processing Record 80 of Set 7 | dauphin
# Processing Record 81 of Set 7 | shaoguan
# Processing Record 82 of Set 7 | prince george
# Processing Record 83 of Set 7 | port lincoln
# Processing Record 84 of Set 7 | riyadh
# Processing Record 85 of Set 7 | la macarena
# Processing Record 86 of Set 7 | pandaria
# Processing Record 87 of Set 7 | abilene
# Processing Record 88 of Set 7 | ornskoldsvik
# Processing Record 89 of Set 7 | limbang
# Processing Record 90 of Set 7 | ayan
# Processing Record 91 of Set 7 | ceske velenice
# Processing Record 92 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 93 of Set 7 | ardabil
# Processing Record 94 of Set 7 | sao jose da coroa grande
# Processing Record 95 of Set 7 | malumfashi
# Processing Record 96 of Set 7 | nelson
# Processing Record 97 of Set 7 | miles city
# Processing Record 98 of Set 7 | paka
# Processing Record 99 of Set 7 | dingzhou
# Processing Record 100 of Set 7 | ahipara
# Processing Record 1 of Set 8 | nuristan
# Processing Record 2 of Set 8 | axim
# Processing Record 3 of Set 8 | nalut
# Processing Record 4 of Set 8 | morgan city
# Processing Record 5 of Set 8 | sisimiut
# Processing Record 6 of Set 8 | pontianak
# Processing Record 7 of Set 8 | sobolevo
# Processing Record 8 of Set 8 | gamba
# Processing Record 9 of Set 8 | eidfjord
# Processing Record 10 of Set 8 | dzaoudzi
# Processing Record 11 of Set 8 | sindor
# Processing Record 12 of Set 8 | zheleznodorozhnyy
# Processing Record 13 of Set 8 | iquique
# Processing Record 14 of Set 8 | fortuna foothills
# Processing Record 15 of Set 8 | sao gabriel da cachoeira
# Processing Record 16 of Set 8 | hun
# Processing Record 17 of Set 8 | corrales
# Processing Record 18 of Set 8 | wanning
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Dikson      RU  73.5069   80.5464     44.08        96
# 1          Mogadishu      SO   2.0371   45.3438     75.61        83
# 2           Thompson      CA  55.7435  -97.8558     59.16        88
# 3    Bambous Virieux      MU -20.3428   57.7575     69.22        88
# 4             Bereda      ES  43.2686   -7.5406     61.57        91
# 5            Rikitea      PF -23.1203 -134.9692     75.34        74
# 6  Sao Joao Da Barra      BR -21.6403  -41.0511     75.29        85
# 7       Puerto Ayora      EC  -0.7393  -90.3518     76.96        89
# 8       Longyearbyen      SJ  78.2186   15.6401     48.04        81
# 9         Hammerfest      NO  70.6634   23.6821     64.85        77
#
#    Cloudiness  Wind Speed Current Description
# 0         100       28.14          light rain
# 1          40       21.36          light rain
# 2          75        8.05       broken clouds
# 3          40        6.91          light rain
# 4          79        6.26       broken clouds
# 5          83       12.82       broken clouds
# 6          31       10.98    scattered clouds
# 7          99        8.01     overcast clouds
# 8          75        5.75       broken clouds
# 9          75        3.44       broken clouds

# %%
#Create CSV file of DF

output_weather_file = "WeatherPy_Database.csv"

#Export the df into a csv

city_data_df.to_csv(output_weather_file, index_label="City_ID")
